# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
# %matplotlib inline

# %% [markdown]
# # Korelacja
#
# Współczynnik korelacji między dwiema zmiennymi odpowiada na pytanie: Czy dwie zmienne są powiązane?
# # Współczynnik korelacji Pearsona
#
# Współczynnik korelacji Pearsona - współczynnik określający poziom zależności liniowej między zmiennymi losowymi.
# # Korelacja rang Spearmana
#
# Korelacja rang Spearmana (lub: korelacja rangowa Spearmana, rho Spearmana) – jedna z nieparametrycznych miar monotonicznej zależności statystycznej między zmiennymi losowymi. Korelacja rangowa przyjmuje zawsze wartości z przedziału $[-1,+1]$. Ich interpretacja jest podobna do klasycznego współczynnika korelacji Pearsona, z jednym zastrzeżeniem: w odróżnieniu od współczynnika Pearsona, który mierzy liniową zależność między zmiennymi, a wszelkie inne związki traktuje jak zaburzone zależności liniowe, korelacja rangowa pokazuje dowolną monotoniczną zależność (także nieliniową).
# # Korelacja Tau Kendalla
#
# Tau Kendalla – statystyka będąca jedną z miar monotonicznej zależności dwóch zmiennych losowych. Służy w praktyce do opisu korelacji między zmiennymi porządkowymi. Tau Kendalla przyjmuje wartości od -1 do 1 włącznie. +1 oznacza, że każda ze zmiennych rośnie przy wzroście drugiej. -1 oznacza że każda maleje przy wzroście drugiej. Tym samym tau Kendalla, podobnie jak korelacja rangowa jest miarą monotonicznej zależności zmiennych losowych.

# %% [markdown]
# # Zad 1.
# Policz korelacje: pearson, spearman, kendall dla zbioru:

# %%
f = lambda x: (x)
x_tr = np.linspace(0., 5, 200)
y_tr = f(x_tr)
x = stats.uniform(1,3).rvs(100)
y = f(x) + stats.norm(0,0.1).rvs(len(x))

print(stats.pearsonr(x, y))
print(stats.spearmanr(x, y))
print(stats.kendalltau(x, y))

plt.figure(figsize=(3,3));
axes = plt.gca()
axes.set_xlim([0,5])
axes.set_ylim([0,5])
plt.plot(x_tr, y_tr, '--k')
_ = plt.plot(x, y, 'ok', ms=3)
# Out:
# (0.99378164845192996, 3.0350374938842562e-95)
# SpearmanrResult(correlation=0.99225922592259219, pvalue=1.3393920426535898e-90)
# KendalltauResult(correlation=0.92686868686868706, pvalue=1.6749539852975471e-42)

# %% [markdown]
# # Zad 2.
# Policz korelacje: pearson, spearman, kendall dla zbioru:

# %%
f = lambda x: (-x+5)
x_tr = np.linspace(0., 5, 200)
y_tr = f(x_tr)
x = stats.uniform(1,3).rvs(100)
y = f(x) + stats.norm(0,0.1).rvs(len(x))

print(stats.pearsonr(x, y))
print(stats.spearmanr(x, y))
print(stats.kendalltau(x, y))

plt.figure(figsize=(3,3));
axes = plt.gca()
axes.set_xlim([0,5])
axes.set_ylim([0,5])
plt.plot(x_tr, y_tr, '--k')
_ = plt.plot(x, y, 'ok', ms=3)
# Out:
# (-0.9939249585187514, 9.7153203101737391e-96)
# SpearmanrResult(correlation=-0.99125112511251112, pvalue=5.2697772346629529e-88)
# KendalltauResult(correlation=-0.93010101010101009, pvalue=8.6947704601949357e-43)

# %% [markdown]
# # Zad 3.
# Policz korelacje: pearson, spearman, kendall dla zbioru:

# %%
f = lambda x: (x)
x_tr = np.linspace(0., 5, 200)
y_tr = f(x_tr)
x = stats.uniform(1,3).rvs(100)
y = f(x) + stats.norm(0,1).rvs(len(x))

print(stats.pearsonr(x, y))
print(stats.spearmanr(x, y))
print(stats.kendalltau(x, y))

plt.figure(figsize=(3,3));
axes = plt.gca()
axes.set_xlim([0,5])
axes.set_ylim([0,5])
plt.plot(x_tr, y_tr, '--k')
_ = plt.plot(x, y, 'ok', ms=3)
# Out:
# (0.74800705218319452, 3.8071904417472136e-19)
# SpearmanrResult(correlation=0.75909990999099908, pvalue=5.6367369248852407e-20)
# KendalltauResult(correlation=0.55070707070707081, pvalue=4.7257930732782076e-16)

# %% [markdown]
# # Zad 4.
# Policz korelacje: pearson, spearman, kendall dla zbioru:

# %%
f = lambda x: ((x-4)*(x-2)*(x-3))
x_tr = np.linspace(0., 5, 200)
y_tr = f(x_tr)
x = stats.uniform(1,3).rvs(100)
y = f(x) + stats.norm(0,0.3).rvs(len(x))

print(stats.pearsonr(x, y))
print(stats.spearmanr(x, y))
print(stats.kendalltau(x, y))

plt.figure(figsize=(3,3));
axes = plt.gca()
axes.set_xlim([0,5])
axes.set_ylim([-2,5])
plt.plot(x_tr, y_tr, '--k')
_ = plt.plot(x, y, 'ok', ms=3)
# Out:
# (0.59276638355126143, 8.1741223026387781e-11)
# SpearmanrResult(correlation=0.43044704470447037, pvalue=7.82003636056129e-06)
# KendalltauResult(correlation=0.30626262626262629, pvalue=6.336909310456707e-06)

# %% [markdown]
# # Zad 5.
# Wygeneruj zbiór tak by
#
# * korelacja pearsona wynosiła około 0.5
# * korelacja spearmana wynosiła około 1
# * korelacja kendalla wynosiła około 1

# %%
f = lambda x: (x**30)
x_tr = np.linspace(0., 5, 200)
y_tr = f(x_tr)
x = stats.uniform(1,3).rvs(100)
y = f(x) + stats.norm(0,0.3).rvs(len(x))

print(stats.pearsonr(x, y))
print(stats.spearmanr(x, y))
print(stats.kendalltau(x, y))

plt.figure(figsize=(3,3));
axes = plt.gca()
axes.set_xlim([0,5])
axes.set_ylim([0,10])
plt.plot(x_tr, y_tr, '--k')
_ = plt.plot(x, y, 'ok', ms=3)
# Out:
# (0.50139755986675449, 1.0744570753295986e-07)
# SpearmanrResult(correlation=0.99999999999999989, pvalue=0.0)
# KendalltauResult(correlation=1.0000000000000002, pvalue=3.4803014072314879e-49)

# %% [markdown]
# # Zad 6.
# Proszę wygenerować dane tak by 1. i 3. współrzędna były skorelowane a pozostałe nie. Proszę zwizualizować tą zależność za pomocą
#
# * sns.pairplot
# * sns.heatmap

# %%
n=1000
x1=stats.norm(0,1).rvs(n)
x2=stats.norm(0,1).rvs(n)
x4=stats.norm(0,1).rvs(n)
X=np.stack((x1,x2, 2*x1, x4 ),1)

df=pd.DataFrame(X)
sns.pairplot(df)
plt.show()
sns.set(style="darkgrid")

corr = df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(7, 5))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
_ = sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3,
            square=True, xticklabels=5, yticklabels=5,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)

# %% [markdown]
# # Zad 7.
# Wygeneruj dane 10. wymiarowe tak by
#
# * 1 3 5 współrzędne były skorelowane ze sobą
# * 7 8 współrzędne były skorelowane ze sobą
# * pozostałe były nieskorelowane

# %%
n=1000
x1=stats.norm(0,1).rvs(n)
x2=stats.norm(0,1).rvs(n)
x4=stats.norm(0,1).rvs(n)
x6=stats.norm(0,1).rvs(n)
x7=stats.norm(0,1).rvs(n)
x9=stats.norm(0,1).rvs(n)
x10=stats.norm(0,1).rvs(n)
X=np.stack((x1, x2, 2*x1, x4, 3*x1, x6, x7, 2*x7, x9, x10), 1)

df=pd.DataFrame(X)
sns.pairplot(df)
sns.set(style="darkgrid")

# %% [markdown]
# # Zad 8.
# Proszę wygenerować próbkę z rozkładu Normalnego m = [0,0] oraz \Sigma = [[4.40, -2.75], [-2.75, 5.50]]
#
# * Proszę policzyć średnią oraz macierz kowariancji próbki.
# * Policz wektory i wartości własne macierzy kowariancji.
# * Narysuj na jednym wykresie: próbkę poziomice rozkładu normalnego i wektory własne macierzy kowariancji przeskalowane przez wartości własne: 2*sqrt(eigenvalue)

# %%
mean = [0, 0]
cov = np.array([[4.40, -2.75], [-2.75, 5.50]])
n_samples = 1000

samples = np.random.multivariate_normal(mean, cov, size=n_samples)
sample_mean = np.mean(samples, axis=0)
sample_cov = np.cov(samples, rowvar=False)

print("sample mean", sample_mean)
print("sample cov", sample_cov)

w, v = np.linalg.eig(sample_cov)
print("eigenvectors", v)
print("eigenvalues", w)

new_v = v * (2 * np.sqrt(w))

print("new eigenvectors", v)

plt.figure(figsize=(6, 6))
axes = plt.gca()
axes.set_xlim([-8,10])
axes.set_ylim([-8,10])

plt.scatter(samples[:,0], samples[:,1], alpha=0.5)
plt.arrow(sample_mean[0], sample_mean[1], new_v[0, 0], new_v[1, 0], fc="k", ec="k",
head_width=0.2, head_length=0.1, width=0.05)
plt.arrow(sample_mean[0], sample_mean[1], new_v[0, 1], new_v[1, 1], fc="k", ec="k",
head_width=0.2, head_length=0.1, width=0.05)

from matplotlib import mlab, cm

X = np.arange(-8, 10, 0.01)
Y = np.arange(-8, 10, 0.01)
X, Y = np.meshgrid(X, Y)
Z = mlab.bivariate_normal(X, Y, 
                      np.sqrt(sample_cov[0, 0]), np.sqrt(sample_cov[1, 1]),
                      mean[0], mean[1], sample_cov[1, 0])

levels = np.arange(0.0, 0.8, 0.01)
_ = plt.contour(X, Y, Z, levels, c='r')
# Out:
# sample mean [ 0.03334684 -0.04819297]
# sample cov [[ 4.10175064 -2.51358399]
#  [-2.51358399  5.23625433]]
# eigenvectors [[-0.78106927  0.62444439]
#  [-0.62444439 -0.78106927]]
# eigenvalues [ 2.09220619  7.24579877]
# new eigenvectors [[-0.78106927  0.62444439]
#  [-0.62444439 -0.78106927]]

# %% [markdown]
# # Zad 9.
# Wylosuj dane z rozkładu normalnego o parametrach m = [0,0] oraz \Sigma = [[4.40, -2.75], [-2.75, 5.50]] wykorzystując próbkę z rozkładu N([0,0],I), gdzie I to macierz identycznościowa.
#
# Szukamy takiego A aby
#
# \Sigma = A^T A.
#
# Aby obliczyć "pierwiastek" z macierzy kowariancji \Sigma można skorzystać z gotowych metod numerycznych - Rozkład Choleskiego.
# https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.linalg.cholesky.html

# %%
from scipy.linalg import cholesky

mean = [0, 0]
cov = np.array([[4.40, -2.75], [-2.75, 5.50]])
n_samples = 1000

id_cov = np.array([[1, 0], [0, 1]])

samples = np.random.multivariate_normal(mean, id_cov, size=n_samples)

A = cholesky(cov)

samples_ = np.dot(samples, A)

plt.figure(figsize=(6, 6))
axes = plt.gca()
axes.set_xlim([-8,10])
axes.set_ylim([-8,10])

_ = plt.scatter(samples_[:,0], samples_[:,1], alpha=0.5)
